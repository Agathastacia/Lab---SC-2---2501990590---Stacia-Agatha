# %% [markdown]
# <a href="https://colab.research.google.com/github/Agathastacia/Lab---SC-2---2501990590---Stacia-Agatha/blob/main/Lab_SC_2_Pandas_and_matplotlib_library_2501990590_Stacia_Agatha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Solve System of Linear Equations in Phyton**

# %% [markdown]
# ### **Pandas and Matplotlib library**

# %% [markdown]
# **Matplotlib**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [0, 1, 2, 3]
y = [0, 1, 4, 9]
plt.plot(x, y)
plt.show()

# %% [markdown]
# **Pandas**

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();
